# %% [markdown]
# # Assignment #5

# %% [markdown]
# ## Due: November 17, 2020

# %% [markdown]
# Read in the [Volcano eruptions](https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/eruptions.csv) data from the TidyTuesday project with `read_csv`.

# %% [markdown]
# Use the `print` function to find the number of rows and columns in the data.

# %%
library(tidyverse)

df = read_csv("https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/eruptions.csv")
print(df)
# Out:
# Warning message:
# “replacing previous import ‘vctrs::data_frame’ by ‘tibble::data_frame’ when loading ‘dplyr’”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.1
# ✔ tidyr   1.1.1     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Parsed with column specification:
# cols(
#   volcano_number = col_double(),
#   volcano_name = col_character(),
#   eruption_number = col_double(),
#   eruption_category = col_character(),
#   area_of_activity = col_character(),
#   vei = col_double(),
#   start_year = col_double(),
#   start_month = col_double(),
#   start_day = col_double(),
#   evidence_method_dating = col_character(),
#   end_year = col_double(),
#   end_month = col_double(),
#   end_day = col_double(),
#   latitude = col_double(),
#   longitude = col_double()
# )
# # A tibble: 11,178 x 15
#    volcano_number volcano_name eruption_number eruption_catego… area_of_activity
#             <dbl> <chr>                  <dbl> <chr>            <chr>
#  1         266030 Soputan                22354 Confirmed Erupt… NA
#  2         343100 San Miguel             22355 Confirmed Erupt… NA
#  3         233020 Fournaise, …           22343 Confirmed Erupt… NA
#  4         345020 Rincon de l…           22346 Confirmed Erupt… NA
#  5         353010 Fernandina             22347 Confirmed Erupt… NA
#  6         273070 Taal                   22344 Confirmed Erupt… NA
#  7         282050 Kuchinoerab…           22345 Confirmed Erupt… NA
#  8         241040 Whakaari/Wh…           22338 Confirmed Erupt… 1978/90 Crater …
#  9         311060 Semisopochn…           22341 Confirmed Erupt… NA
# 10         284096 Nishinoshima           22340 Confirmed Erupt… NA
# # … with 11,168 more rows, and 10 more variables: vei <dbl>, start_year <dbl>,
# #   start_month <dbl>, start_day <dbl>, evidence_method_dating <chr>,
# #   end_year <dbl>, end_month <dbl>, end_day <dbl>, latitude <dbl>,
# #   longitude <dbl>

# %% [markdown]
# Using `group_by`, `summarize` (or `count`), and `arrange`, find the volcano with the most recorded eruptions in the data. Remeber the [desc](https://dplyr.tidyverse.org/reference/desc.html) function can be used to sort in descending order.

# %%
erup_df = df %>% group_by(volcano_name) %>% count() %>% arrange(desc(n))
erup_df
# Out:
#     volcano_name             n
# 1   Etna                     241
# 2   Fournaise, Piton de la   194
# 3   Asosan                   186
# 4   Villarrica               164
# 5   Asamayama                147
# 6   Katla                    132
# 7   Klyuchevskoy             111
# 8   Mauna Loa                110
# 9   Merapi                   110
# 10  Izu-Oshima               108
# 11  Sheveluch                105
# 12  Redoubt                  101
# 13  Kilauea                   96
# 14  Gamalama                  87
# 15  Colima                    86
# 16  Grimsvotn                 86
# 17  Cotopaxi                  85
# 18  Kirishimayama             85
# 19  Fuego                     79
# 20  Tongariro                 79
# 21  Unknown Source            77
# 22  Raung                     69
# 23  Tengger Caldera           69
# 24  Marapi                    68
# 25  Fujisan                   67
# 26  Mayon                     66
# 27  Ruapehu                   66
# 28  Bezymianny                65
# 29  Hekla                     65
# 30  Semeru                    65
# 225 211060         Etna         13500           Confirmed Eruption
# 226 211060         Etna         13499           Confirmed Eruption
# 227 211060         Etna         13498           Uncertain Eruption
# 228 211060         Etna         13497           Confirmed Eruption
# 229 211060         Etna         13496           Uncertain Eruption
# 230 211060         Etna         13495           Confirmed Eruption
# 231 211060         Etna         13494           Confirmed Eruption
# 232 211060         Etna         13493           Discredited Eruption
# 233 211060         Etna         13492           Confirmed Eruption
# 234 211060         Etna         13491           Confirmed Eruption
# 235 211060         Etna         13490           Confirmed Eruption
# 236 211060         Etna         13489           Confirmed Eruption
# 237 211060         Etna         13488           Confirmed Eruption
# 238 211060         Etna         13487           Confirmed Eruption
# 239 211060         Etna         13486           Confirmed Eruption
# 240 211060         Etna         13485           Confirmed Eruption
# 241 211060         Etna         13484           Confirmed Eruption
#     area_of_activity                             vei start_year start_month
# 1   New Southeast Crater (NSEC)                  2   2013        9
# 2   Bocca Nuova, NE and SE Craters               1   2010        8
# 3   SE Crater                                    2   2010        4
# 4   East base of NE Crater (3000-2650 m)         1   2008        5
# 5   Bocca Nuova, SE Crater and flank vents       2   2007        3
# 6   SE Crater & flank vents; NE Crater           2   2006        7
# 7   Bocca Nuova                                  1   2005       12
# 8   SE Crater, SE flank (3000-2320 m)            1   2004        9
# 9   Central Crater                               1   2004        2
# 10  NE Crater                                    1   2003        3
# 11  NE Rift (3100-1900 m), S flank (2850-2600 m) 3   2002       10
# 12  Central Crater, NE Crater                    1   2001       12
# 13  S to NE flanks (3100-2100 m)                 2   2001        7
# 14  Central Crater, NE Crater, SE Crater         3   1994        6
# 15  Central Crater, NE Crater                    1   1993        8
# 16  NE Crater                                    1   1993        2
# 17  SE flank (3100-2800 m and 2400-2100 m)       2   1991       12
# 18  SE and NE Craters                            3   1989       12
# 19  SE Crater, SE and NE flanks                  2   1989        9
# 20  SE Crater                                    1   1988       10
# 21  NE and SE Craters                            2   1987        3
# 22  Valle del Bove (3050-2180 m)                 2   1986       10
# 23  SE Crater                                    2   1986        3
# 24  SE Crater and SE flank (2750-2420 m)         1   1985       12
# 25  SE Crater, south flank (2620-2480 m)         1   1985        3
# 26  NE Crater                                    3   1984        7
# 27  SE Crater                                    1   1984        4
# 28  South flank (2680-2250 m)                    1   1983        3
# 29  NE Crater                                    2   1981       11
# 30  NNW flank (2550-1140 m)                      2   1981        3
# ⋮   ⋮                                            ⋮   ⋮          ⋮
# 212 NA                                           NA    -10       0
# 213 NA                                           NA    -32      12
# 214 East side ?                                  NA    -36       7
# 215 NA                                            3    -44       3
# 216 West flank and summit ?                      NA    -49       0
# 217 NA                                           NA    -56       0
# 218 NA                                           NA    -61       0
# 219 S flank, summit (Cratere del Piano caldera)   5   -122       0
# 220 NA                                           NA   -126       6
# 221 NA                                           NA   -135       0
# 222 NA                                           NA   -141      12
# 223 NA                                           NA   -350       0
# 224 SE flank (700 m, Monte Gorna)                NA   -396       4
# 225 South flank (Monte Arso)                     NA   -425       3
# 226 South flank ?                                NA   -479       8
# 227 NA                                           NA   -565       0
# 228 South ?, Mt. Mompilieri ?                    NA   -695       0
# 229 NA                                           NA   -735       0
# 230 South flank (Monte Salto del Cane)           NA  -1050       0
# 231 NA                                           NA  -1420       0
# 232 NA                                           NA  -1470       0
# 233 NA                                            5  -1500       0
# 234 NA                                           NA  -1980       0
# 235 NA                                           NA  -2330       0
# 236 NA                                           NA  -3050       0
# 237 NA                                           NA  -3390       0
# 238 NA                                           NA  -3510       0
# 239 NA                                           NA  -4150       0
# 240 NA                                           NA  -5150       0
# 241 NA                                           NA  -6190       0
#     start_day evidence_method_dating    end_year end_month end_day latitude
# 1    3        Historical Observations   2020      4        17      37.748
# 2   25        Historical Observations   2013      4        27      37.748
# 3    8        Historical Observations   2010      4         8      37.748
# 4   13        Historical Observations   2009      7         4      37.748
# 5   19        Historical Observations   2008      5        16      37.748
# 6   14        Historical Observations   2006     12        15      37.748
# 7   16        Historical Observations   2005     12        22      37.748
# 8    7        Historical Observations   2005      3         8      37.748
# 9   12        Historical Observations   2004      2        14      37.748
# 10   8        Historical Observations   2003     11         9      37.748
# 11  26        Historical Observations   2003      1        28      37.748
# 12  16        Historical Observations   2002     10        30      37.748
# 13  17        Historical Observations   2001      8         9      37.748
# 14  17        Historical Observations   2001      7        17      37.748
# 15   3        Historical Observations   1993     10        13      37.748
# 16   3        Historical Observations   1993      2         3      37.748
# 17  14        Historical Observations   1993      3        30      37.748
# 18  16        Historical Observations   1992      5        23      37.748
# 19  11        Historical Observations   1989     10         9      37.748
# 20   2        Historical Observations   1989      6        30      37.748
# 21   8        Historical Observations   1987      5        16      37.748
# 22  30        Historical Observations   1987      3         1      37.748
# 23  16        Historical Observations   1986     10        31      37.748
# 24  19        Historical Observations   1985     12        31      37.748
# 25   8        Historical Observations   1985      7        13      37.748
# 26  20        Historical Observations   1986      9        24      37.748
# 27  28        Historical Observations   1984     10        18      37.748
# 28  28        Historical Observations   1983      8         6      37.748
# 29  26        Historical Observations   1981     11        26      37.748
# 30  17        Historical Observations   1981      3        23      37.748
# ⋮   ⋮         ⋮                         ⋮        ⋮         ⋮       ⋮
# 212  0        NA                          NA     NA        NA      37.748
# 213 31        Historical Observations     NA     NA        NA      37.748
# 214 15        Historical Observations    -35      0         0      37.748
# 215  0        Historical Observations     NA     NA        NA      37.748
# 216  0        Historical Observations     NA     NA        NA      37.748
# 217  0        NA                          NA     NA        NA      37.748
# 218  0        NA                          NA     NA        NA      37.748
# 219  0        Historical Observations     NA     NA        NA      37.748
# 220  0        Historical Observations     NA     NA        NA      37.748
# 221  0        Historical Observations     NA     NA        NA      37.748
# 222 31        Historical Observations     NA     NA        NA      37.748
# 223  0        NA                          NA     NA        NA      37.748
# 224 15        Historical Observations     NA     NA        NA      37.748
# 225 15        Historical Observations   -424      0         0      37.748
# 226  0        Historical Observations   -475      0         0      37.748
# 227  0        NA                          NA     NA        NA      37.748
# 228  0        Historical Observations     NA     NA        NA      37.748
# 229  0        NA                          NA     NA        NA      37.748
# 230  0        Radiocarbon (uncorrected)   NA     NA        NA      37.748
# 231  0        Radiocarbon (corrected)     NA     NA        NA      37.748
# 232  0        NA                          NA     NA        NA      37.748
# 233  0        Historical Observations     NA     NA        NA      37.748
# 234  0        Radiocarbon (uncorrected)   NA     NA        NA      37.748
# 235  0        Radiocarbon (uncorrected)   NA     NA        NA      37.748
# 236  0        Radiocarbon (uncorrected)   NA     NA        NA      37.748
# 237  0        Radiocarbon (uncorrected)   NA     NA        NA      37.748
# 238  0        Radiocarbon (uncorrected)   NA     NA        NA      37.748
# 239  0        Radiocarbon (uncorrected)   NA     NA        NA      37.748
# 240  0        Radiocarbon (uncorrected)   NA     NA        NA      37.748
# 241  0        Radiocarbon (uncorrected)   NA     NA        NA      37.748
#     longitude
# 1   14.999
# 2   14.999
# 3   14.999
# 4   14.999
# 5   14.999
# 6   14.999
# 7   14.999
# 8   14.999
# 9   14.999
# 10  14.999
# 11  14.999
# 12  14.999
# 13  14.999
# 14  14.999
# 15  14.999
# 16  14.999
# 17  14.999
# 18  14.999
# 19  14.999
# 20  14.999
# 21  14.999
# 22  14.999
# 23  14.999
# 24  14.999
# 25  14.999
# 26  14.999
# 27  14.999
# 28  14.999
# 29  14.999
# 30  14.999
# ⋮   ⋮
# 212 14.999
# 213 14.999
# 214 14.999
# 215 14.999
# 216 14.999
# 217 14.999
# 218 14.999
# 219 14.999
# 220 14.999
# 221 14.999
# 222 14.999
# 223 14.999
# 224 14.999
# 225 14.999
# 226 14.999
# 227 14.999
# 228 14.999
# 229 14.999
# 230 14.999
# 231 14.999
# 232 14.999
# 233 14.999
# 234 14.999
# 235 14.999
# 236 14.999
# 237 14.999
# 238 14.999
# 239 14.999
# 240 14.999
# 241 14.999

# %% [markdown]
# Make a bar chart of eruption count by volcano_name. The bars should be sorted by frequency using `fct_infreq`. "Lump" the low frequency values into an "Other" category with `fct_lump`.
#
# **Bonus:** Can you remove the "Other" category with the `filter` function if it dominates the chart?

# %%
data = df %>% mutate(lump = volcano_name %>% fct_lump(n = 20) %>% fct_infreq() %>% fct_rev())
data2 = data %>% filter(lump != "Other")
p = ggplot(data2, aes(y=lump)) + geom_bar() +
    labs(y = "Volcanos", x = "Number of Eruptions")
p
# Out:
# plot without title

# %% [markdown]
# Using `mutate` generate a column that represents the span of each eruption in years (i.e. "end_year" minus "start_year"). Use `filter` to exclude eruption spans shorter than ten years.
#
# - Plot a histogram of your generated column (i.e. eruption spans greater than ten years).
# - Which volcano(s) has/have the longest eruption span in years? How long did the eruption last?

# %%
data = df %>% mutate(span = end_year - start_year) %>% filter(span >= 10) %>% arrange(desc(span))
head(data)
p = ggplot(data, aes(x=span)) + geom_histogram(bins=20) +
    labs(x = "Span of Each Eruption")
p
#Longest eruption span = Stromboli, 299 years
# Out:
#   volcano_number volcano_name eruption_number eruption_category
# 1 211040         Stromboli    13425           Confirmed Eruption
# 2 384010         Fogo         13128           Confirmed Eruption
# 3 257100         Yasur        15355           Confirmed Eruption
# 4 352090         Sangay       11647           Confirmed Eruption
# 5 342030         Santa Maria  10626           Confirmed Eruption
# 6 268010         Dukono       16577           Confirmed Eruption
#   area_of_activity                      vei start_year start_month start_day
# 1 Summit craters and Sciara del Fuoco   3   1558       0            0
# 2 Pico                                  1   1500       0            0
# 3 NA                                    3   1774       7            2
# 4 NA                                    3   1728       9           30
# 5 SW flank (Santiaguito)                3   1922       6           22
# 6 Malupang Magiwe and Malupang Warirang 3   1933       8           13
#   evidence_method_dating  end_year end_month end_day latitude longitude span
# 1 Historical Observations 1857     0          0       38.789   15.213   299
# 2 Historical Observations 1761     0          0       14.950  -24.350   261
# 3 Historical Observations 2020     4         17      -19.532  169.447   246
# 4 Historical Observations 1916     0          0       -2.005  -78.341   188
# 5 Historical Observations 2020     4         17       14.757  -91.552    98
# 6 Historical Observations 2020     4         17        1.693  127.894    87
# plot without title
